# %%
import pandas as pd 
dataset = pd.read_csv('Emotion_classify_Data.csv')
dataset.shape
# Out:
# (5937, 2)

# %%
dataset
# Out:
#                                                 Comment Emotion
# 0     i seriously hate one subject to death but now ...    fear
# 1                    im so full of life i feel appalled   anger
# 2     i sit here to write i start to dig out my feel...    fear
# 3     ive been really angry with r and i feel like a...     joy
# 4     i feel suspicious if there is no one outside l...    fear
# ...                                                 ...     ...
# 5932                 i begun to feel distressed for you    fear
# 5933  i left feeling annoyed and angry thinking that...   anger
# 5934  i were to ever get married i d have everything...     joy
# 5935  i feel reluctant in applying there because i w...    fear
# 5936  i just wanted to apologize to you because i fe...   anger
#
# [5937 rows x 2 columns]

# %%
dataset['Emotion'].value_counts()
# Out:
# Emotion
# anger    2000
# joy      2000
# fear     1937
# Name: count, dtype: int64

# %%
dataset['Emotion_num'] = dataset['Emotion'].map({
  'anger' : 0,
  'joy' : 1,
  'fear' : 2
})

# %%
X = dataset['Comment']
y = dataset['Emotion_num']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21, stratify=y)

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier

rfp = Pipeline([
     ('vectorizer_tfidf',TfidfVectorizer()), 
     ('Random Forest', RandomForestClassifier())         
])

rfp.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer_tfidf', TfidfVectorizer()),
#                 ('Random Forest', RandomForestClassifier())])

# %%
y_pred = rfp.predict(X_test)

from sklearn.metrics import classification_report
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.87      0.91       400
#            1       0.87      0.93      0.90       400
#            2       0.91      0.92      0.91       388
#
#     accuracy                           0.91      1188
#    macro avg       0.91      0.91      0.91      1188
# weighted avg       0.91      0.91      0.91      1188

# %%
from sklearn.naive_bayes import MultinomialNB

multip = Pipeline([
     ('vectorizer_tfidf',TfidfVectorizer()),    
     ('Multi NB', MultinomialNB())         
])

multip.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer_tfidf', TfidfVectorizer()),
#                 ('Multi NB', MultinomialNB())])

# %%
y_pred2 = multip.predict(X_test)

cr = classification_report(y_test, y_pred2)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89       400
#            1       0.91      0.87      0.89       400
#            2       0.89      0.90      0.90       388
#
#     accuracy                           0.89      1188
#    macro avg       0.89      0.89      0.89      1188
# weighted avg       0.89      0.89      0.89      1188

# %%
from sklearn.neighbors import KNeighborsClassifier

knnp = Pipeline([
     ('vectorizer_tfidf',TfidfVectorizer()),    
     ('KNN', KNeighborsClassifier())         
])

knnp.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer_tfidf', TfidfVectorizer()),
#                 ('KNN', KNeighborsClassifier())])

# %%
y_pred3 = knnp.predict(X_test)

cr = classification_report(y_test, y_pred3)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.81      0.73       400
#            1       0.75      0.69      0.72       400
#            2       0.80      0.70      0.74       388
#
#     accuracy                           0.73      1188
#    macro avg       0.74      0.73      0.73      1188
# weighted avg       0.74      0.73      0.73      1188

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

def preperocess(text):
  doc = nlp(text)
  filtered_tokens = []

  for token in doc:
    if token.is_stop and token.is_punct:
      continue
    filtered_tokens.append(token.lemma_)

  return ' '.join(filtered_tokens)

# %%
dataset['preprocessed_data'] = dataset['Comment'].apply(preperocess)

# %%
X = dataset['preprocessed_data']
y = dataset['Emotion_num']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21, stratify=y)

# %%
rfp = Pipeline([
     ('vectorizer_tfidf',TfidfVectorizer()), 
     ('Random Forest', RandomForestClassifier())         
])

rfp.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer_tfidf', TfidfVectorizer()),
#                 ('Random Forest', RandomForestClassifier())])

# %%
y_pred = rfp.predict(X_test)

from sklearn.metrics import classification_report
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88       400
#            1       0.84      0.93      0.88       400
#            2       0.90      0.91      0.90       388
#
#     accuracy                           0.89      1188
#    macro avg       0.89      0.89      0.89      1188
# weighted avg       0.89      0.89      0.89      1188

# %%
from sklearn.naive_bayes import MultinomialNB

multip = Pipeline([
     ('vectorizer_tfidf',TfidfVectorizer()),    
     ('Multi NB', MultinomialNB())         
])

multip.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer_tfidf', TfidfVectorizer()),
#                 ('Multi NB', MultinomialNB())])

# %%
y_pred2 = multip.predict(X_test)

cr = classification_report(y_test, y_pred2)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.88       400
#            1       0.90      0.89      0.89       400
#            2       0.88      0.88      0.88       388
#
#     accuracy                           0.89      1188
#    macro avg       0.89      0.89      0.89      1188
# weighted avg       0.89      0.89      0.89      1188

# %%
from sklearn.neighbors import KNeighborsClassifier

knnp = Pipeline([
     ('vectorizer_tfidf',TfidfVectorizer()),    
     ('KNN', KNeighborsClassifier())         
])

knnp.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer_tfidf', TfidfVectorizer()),
#                 ('KNN', KNeighborsClassifier())])

# %%
y_pred3 = knnp.predict(X_test)

cr = classification_report(y_test, y_pred3)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.80      0.73       400
#            1       0.75      0.68      0.71       400
#            2       0.79      0.70      0.74       388
#
#     accuracy                           0.73      1188
#    macro avg       0.73      0.73      0.73      1188
# weighted avg       0.73      0.73      0.73      1188
